# %% [markdown]
# ## (a)
# - \alpha_i \in [0, 1], \sum \alpha_i = 1
# - When k_i and q are very similar/parallel compared with other k_j's.
# - The output c is largely influenced by \v_i and is very close to it numerically
# - If we consider a transplanting model, this indicates the alignment relationship between the two corresponding vectors
# ## (b)
# ![01279ac817bb83f3c110a572b3707ef.jpg](attachment:01279ac817bb83f3c110a572b3707ef.jpg)
# ## (c)
# ![012cc0322074fa2670f6f617717c08f.jpg](attachment:012cc0322074fa2670f6f617717c08f.jpg)
# ## (d)
# ![b6a466a84980680959fef51e6acb497.jpg](attachment:b6a466a84980680959fef51e6acb497.jpg)
